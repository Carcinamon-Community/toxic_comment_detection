# %%
import csv
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import regularizers
import matplotlib.pyplot as plt

# %%
NUM_WORDS = 1000
EMBEDDING_DIM = 100
MAXLEN = 200
PADDING = 'post'
OOV_TOKEN = "<OOV>"
TRAIN_FILE = "processed_train.csv"
TEST_FILE = "processed_test.csv"
STOPWORDS_FILE = "stopwordbahasa.csv"
STOPWORDS = []
num_classes = 4
learning_rate = 0.001
batch_size = 16
num_epochs = 10

# %%
def load_stopwords(stopwords_file=STOPWORDS_FILE):
    """
    Loads the stopwords from the stopwords file
    
    Args:
        stopwords_file (string): path to the stopwords file
    Returns:
        stopwords (list): list of stopwords
    """
    with open('/content/drive/MyDrive/Colab Notebooks/stopwordbahasa.csv', 'r') as f:
        stopwords = []
        reader = csv.reader(f)
        for row in reader:
            stopwords.append(row[0])
        
        return stopwords

STOPWORDS = load_stopwords(STOPWORDS_FILE)

# %%
STOPWORDS[:5]
# Out:
# ['ada', 'adalah', 'adanya', 'adapun', 'agak']

# %%
def remove_stopwords(sentence, stopwords=STOPWORDS):
    """
    Removes a list of stopwords
    
    Args:
        sentence (string): sentence to remove the stopwords from
        stopwords (list): list of stopwords to remove from the sentence
        
    Returns:
        sentence (string): lowercase sentence without the stopwords
    """
    sentence = sentence.lower()
    words = sentence.split()
    no_stopwords = [word for word in words if word not in stopwords]
    sentence = " ".join(no_stopwords)
    return sentence

# %%
def parse_data_from_file(filename):
    """
    Extracts sentences and labels from a CSV file
    
    Args:
        filename (string): path to the CSV file
    
    Returns:
        sentences, labels (list of string, list of string): tuple containing lists of sentences and labels
    """
    sentences = []
    labels = []
    with open(filename, 'r', encoding="utf8") as csvfile:
        reader = csv.reader(csvfile, delimiter=',')
        next(reader)
        for row in reader:
            toxicity = int(row[2]) + int(row[3]) + int(row[4]) + int(row[5])
            if toxicity > 0:
                labels.append(1)
            else:
                labels.append(0)
            sentence = row[6]
            sentence = remove_stopwords(sentence)
            sentences.append(sentence)

    return sentences, np.array(labels)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
test_sentences, test_labels = parse_data_from_file("/content/drive/MyDrive/Colab Notebooks/processed_test.csv")
train_sentences, train_labels  = parse_data_from_file("/content/drive/MyDrive/Colab Notebooks/processed_train.csv")

# %%
print(train_sentences[0])
print(train_labels[0])

print(test_sentences[0])
print(test_labels[0])

# number of sentences in the training set
print(f"No. of sentences in the training set: {len(train_sentences)}")

# number of sentences in the test set
print(f"No. of sentences in the test set: {len(test_sentences)}")

# shape of the labels in the training set
print(f"Shape of the labels in the training set: {train_labels.shape}")

# shape of the labels in the test set
print(f"Shape of the labels in the test set: {test_labels.shape}")
# Out:
# jabar provinsi barokah nwoi anjing bodoh npropinsi ngerusak ngebakar gereja jatim provinsi lumbung nasbung jatim npropinsi penghasil gembong teroris jateng lumbung nasbung jateng ngarang stereotip piliah pilih nbangsat pecun
# 1
# spanduk prof video orasi buku lainlain sngat heran rkyat tolol jls niat hizbut tahrir tegakan khilafah ganti negara kesatuan republik indonesia berkilah tegakan khilafah munafik apanya khilafah
# 1
# No. of sentences in the training set: 6995
# No. of sentences in the test set: 778
# Shape of the labels in the training set: (6995,)
# Shape of the labels in the test set: (778,)

# %%
def fit_tokenizer(train_sentences, num_words, oov_token):
    """
    Instantiates the Tokenizer class on the training sentences
    
    Args:
        train_sentences (list of string): lower-cased sentences without stopwords to be used for training
        num_words (int) - number of words to keep when tokenizing
        oov_token (string) - symbol for the out-of-vocabulary token
    
    Returns:
        tokenizer (object): an instance of the Tokenizer class containing the word-index dictionary
    """
    
    ### START CODE HERE
    
    # Instantiate the Tokenizer class, passing in the correct values for num_words and oov_token
    tokenizer = Tokenizer(num_words=num_words, oov_token=oov_token)
    
    # Fit the tokenizer to the training sentences
    tokenizer.fit_on_texts(train_sentences)
    
    ### END CODE HERE
    
    return tokenizer

# %%
# Test function
tokenizer = fit_tokenizer(train_sentences, NUM_WORDS, OOV_TOKEN)
word_index = tokenizer.word_index

print(f"Vocabulary contains {len(word_index)} words\n")
print("<OOV> token included in vocabulary" if "<OOV>" in word_index else "<OOV> token NOT included in vocabulary")
# Out:
# Vocabulary contains 28899 words
#
# <OOV> token included in vocabulary

# %%
def seq_and_pad(sentences, tokenizer, padding, maxlen):
    """
    Generates an array of token sequences and pads them to the same length
    
    Args:
        sentences (list of string): list of sentences to tokenize and pad
        tokenizer (object): Tokenizer instance containing the word-index dictionary
        padding (string): type of padding to use
        maxlen (int): maximum length of the token sequence
    
    Returns:
        padded_sequences (array of int): tokenized sentences padded to the same length
    """ 
    
    ### START CODE HERE
       
    # Convert sentences to sequences
    sequences = tokenizer.texts_to_sequences(sentences)
    
    # Pad the sequences using the correct padding and maxlen
    padded_sequences = pad_sequences(sequences, padding=padding, maxlen=maxlen)
    
    ### END CODE HERE
    
    return padded_sequences

# %%
# Test your function
train_padded_seq = seq_and_pad(train_sentences, tokenizer, PADDING, MAXLEN)
test_padded_seq = seq_and_pad(test_sentences, tokenizer, PADDING, MAXLEN)

print(f"Padded training sequences have shape: {train_padded_seq.shape}\n")
print(f"Padded validation sequences have shape: {test_padded_seq.shape}")
# Out:
# Padded training sequences have shape: (6995, 200)
#
# Padded validation sequences have shape: (778, 200)

# %%
def create_model(num_words, embedding_dim, maxlen):
    tf.random.set_seed(123)
    
    model = tf.keras.Sequential([ 
        tf.keras.layers.Embedding(num_words, embedding_dim, input_length=maxlen),
        tf.keras.layers.GlobalAveragePooling1D(),
        tf.keras.layers.Dense(128, activation="relu", kernel_regularizer=regularizers.l2(0.001)),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(64, activation="relu", kernel_regularizer=regularizers.l2(0.001)),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(1, activation="sigmoid")  
    ])
    
    model.compile(
        loss=tf.keras.losses.BinaryCrossentropy(),
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
    )

    return model

# %%
model = create_model(NUM_WORDS, EMBEDDING_DIM, MAXLEN)

history = model.fit(train_padded_seq, train_labels, epochs=90, validation_data=(test_padded_seq, test_labels))
# Out:
# Epoch 1/90
# Exception ignored in: <function _xla_gc_callback at 0x7f265dee71c0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/jax/_src/lib/__init__.py", line 103, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:
# 219/219 [==============================] - 58s 9ms/step - loss: 0.7445 - accuracy: 0.5593 - precision_10: 0.5633 - recall_10: 0.9580 - val_loss: 0.6974 - val_accuracy: 0.5553 - val_precision_10: 0.5553 - val_recall_10: 1.0000
# Epoch 2/90
# 219/219 [==============================] - 2s 8ms/step - loss: 0.6822 - accuracy: 0.5697 - precision_10: 0.5671 - recall_10: 0.9888 - val_loss: 0.6503 - val_accuracy: 0.7211 - val_precision_10: 0.7087 - val_recall_10: 0.8449
# Epoch 3/90
# 219/219 [==============================] - 2s 8ms/step - loss: 0.5624 - accuracy: 0.7457 - precision_10: 0.7339 - recall_10: 0.8585 - val_loss: 0.5011 - val_accuracy: 0.7982 - val_precision_10: 0.8220 - val_recall_10: 0.8125
# Epoch 4/90
# 219/219 [==============================] - 2s 11ms/step - loss: 0.4915 - accuracy: 0.8053 - precision_10: 0.8216 - recall_10: 0.8346 - val_loss: 0.4861 - val_accuracy: 0.8123 - val_precision_10: 0.7967 - val_recall_10: 0.8889
# Epoch 5/90
# 219/219 [==============================] - 2s 11ms/step - loss: 0.4552 - accuracy: 0.8232 - precision_10: 0.8385 - recall_10: 0.8486 - val_loss: 0.4722 - val_accuracy: 0.8111 - val_precision_10: 0.8025 - val_recall_10: 0.8750
# Epoch 6/90
# 219/219 [==============================] - 2s 8ms/step - loss: 0.4371 - accuracy: 0.8337 - precision_10: 0.8456 - recall_10: 0.8613 - val_loss: 0.5085 - val_accuracy: 0.7532 - val_precision_10: 0.8974 - val_recall_10: 0.6273
# Epoch 7/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.4217 - accuracy: 0.8436 - precision_10: 0.8582 - recall_10: 0.8643 - val_loss: 0.4668 - val_accuracy: 0.8098 - val_precision_10: 0.8008 - val_recall_10: 0.8750
# Epoch 8/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.4100 - accuracy: 0.8508 - precision_10: 0.8658 - recall_10: 0.8689 - val_loss: 0.4517 - val_accuracy: 0.8111 - val_precision_10: 0.8337 - val_recall_10: 0.8241
# Epoch 9/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.4029 - accuracy: 0.8538 - precision_10: 0.8649 - recall_10: 0.8766 - val_loss: 0.4494 - val_accuracy: 0.8175 - val_precision_10: 0.8469 - val_recall_10: 0.8194
# Epoch 10/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.4030 - accuracy: 0.8500 - precision_10: 0.8660 - recall_10: 0.8671 - val_loss: 0.4540 - val_accuracy: 0.8201 - val_precision_10: 0.8303 - val_recall_10: 0.8495
# Epoch 11/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.4008 - accuracy: 0.8515 - precision_10: 0.8677 - recall_10: 0.8679 - val_loss: 0.4520 - val_accuracy: 0.8136 - val_precision_10: 0.8113 - val_recall_10: 0.8657
# Epoch 12/90
# 219/219 [==============================] - 2s 11ms/step - loss: 0.3848 - accuracy: 0.8609 - precision_10: 0.8746 - recall_10: 0.8783 - val_loss: 0.4581 - val_accuracy: 0.8072 - val_precision_10: 0.8079 - val_recall_10: 0.8565
# Epoch 13/90
# 219/219 [==============================] - 2s 11ms/step - loss: 0.3806 - accuracy: 0.8640 - precision_10: 0.8806 - recall_10: 0.8768 - val_loss: 0.4742 - val_accuracy: 0.7905 - val_precision_10: 0.7717 - val_recall_10: 0.8843
# Epoch 14/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.3826 - accuracy: 0.8633 - precision_10: 0.8755 - recall_10: 0.8822 - val_loss: 0.4505 - val_accuracy: 0.8098 - val_precision_10: 0.8142 - val_recall_10: 0.8519
# Epoch 15/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.3748 - accuracy: 0.8640 - precision_10: 0.8775 - recall_10: 0.8809 - val_loss: 0.4574 - val_accuracy: 0.8033 - val_precision_10: 0.8039 - val_recall_10: 0.8542
# Epoch 16/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.3680 - accuracy: 0.8678 - precision_10: 0.8803 - recall_10: 0.8850 - val_loss: 0.4564 - val_accuracy: 0.8046 - val_precision_10: 0.8365 - val_recall_10: 0.8056
# Epoch 17/90
# 219/219 [==============================] - 2s 8ms/step - loss: 0.3727 - accuracy: 0.8672 - precision_10: 0.8801 - recall_10: 0.8839 - val_loss: 0.4566 - val_accuracy: 0.8059 - val_precision_10: 0.8115 - val_recall_10: 0.8472
# Epoch 18/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.3664 - accuracy: 0.8688 - precision_10: 0.8847 - recall_10: 0.8811 - val_loss: 0.4553 - val_accuracy: 0.8072 - val_precision_10: 0.8065 - val_recall_10: 0.8588
# Epoch 19/90
# 219/219 [==============================] - 2s 8ms/step - loss: 0.3620 - accuracy: 0.8668 - precision_10: 0.8800 - recall_10: 0.8832 - val_loss: 0.4616 - val_accuracy: 0.8033 - val_precision_10: 0.7974 - val_recall_10: 0.8657
# Epoch 20/90
# 219/219 [==============================] - 2s 11ms/step - loss: 0.3645 - accuracy: 0.8718 - precision_10: 0.8856 - recall_10: 0.8862 - val_loss: 0.4615 - val_accuracy: 0.8059 - val_precision_10: 0.8022 - val_recall_10: 0.8634
# Epoch 21/90
# 219/219 [==============================] - 2s 10ms/step - loss: 0.3664 - accuracy: 0.8699 - precision_10: 0.8862 - recall_10: 0.8816 - val_loss: 0.4643 - val_accuracy: 0.8046 - val_precision_10: 0.8084 - val_recall_10: 0.8495
# Epoch 22/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.3560 - accuracy: 0.8779 - precision_10: 0.8884 - recall_10: 0.8951 - val_loss: 0.4551 - val_accuracy: 0.8059 - val_precision_10: 0.8435 - val_recall_10: 0.7986
# Epoch 23/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.3553 - accuracy: 0.8765 - precision_10: 0.8920 - recall_10: 0.8875 - val_loss: 0.5185 - val_accuracy: 0.7648 - val_precision_10: 0.8952 - val_recall_10: 0.6528
# Epoch 24/90
# 219/219 [==============================] - 2s 11ms/step - loss: 0.3515 - accuracy: 0.8776 - precision_10: 0.8917 - recall_10: 0.8903 - val_loss: 0.4631 - val_accuracy: 0.8123 - val_precision_10: 0.8265 - val_recall_10: 0.8380
# Epoch 25/90
# 219/219 [==============================] - 2s 9ms/step - loss: 0.3475 - accuracy: 0.8803 - precision_10: 0.8960 - recall_10: 0.8903 - val_loss: 0.4745 - val_accuracy: 0.7943 - val_precision_10: 0.7833 - val_recall_10: 0.8704
# Epoch 26/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.3508 - accuracy: 0.8753 - precision_10: 0.8867 - recall_10: 0.8921 - val_loss: 0.4583 - val_accuracy: 0.7995 - val_precision_10: 0.8399 - val_recall_10: 0.7894
# Epoch 27/90
# 219/219 [==============================] - 2s 11ms/step - loss: 0.3509 - accuracy: 0.8791 - precision_10: 0.8905 - recall_10: 0.8946 - val_loss: 0.4580 - val_accuracy: 0.7995 - val_precision_10: 0.8333 - val_recall_10: 0.7986
# Epoch 28/90
# 219/219 [==============================] - 3s 12ms/step - loss: 0.3466 - accuracy: 0.8805 - precision_10: 0.8926 - recall_10: 0.8949 - val_loss: 0.4650 - val_accuracy: 0.8072 - val_precision_10: 0.8310 - val_recall_10: 0.8194
# Epoch 29/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.3405 - accuracy: 0.8786 - precision_10: 0.8893 - recall_10: 0.8954 - val_loss: 0.4620 - val_accuracy: 0.8072 - val_precision_10: 0.8205 - val_recall_10: 0.8356
# Epoch 30/90
# 219/219 [==============================] - 2s 8ms/step - loss: 0.3417 - accuracy: 0.8808 - precision_10: 0.8931 - recall_10: 0.8949 - val_loss: 0.4721 - val_accuracy: 0.8033 - val_precision_10: 0.7974 - val_recall_10: 0.8657
# Epoch 31/90
# 219/219 [==============================] - 2s 8ms/step - loss: 0.3359 - accuracy: 0.8822 - precision_10: 0.8914 - recall_10: 0.9000 - val_loss: 0.4963 - val_accuracy: 0.7828 - val_precision_10: 0.7635 - val_recall_10: 0.8819
# Epoch 32/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.3369 - accuracy: 0.8833 - precision_10: 0.8930 - recall_10: 0.9002 - val_loss: 0.4635 - val_accuracy: 0.8059 - val_precision_10: 0.8143 - val_recall_10: 0.8426
# Epoch 33/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.3299 - accuracy: 0.8868 - precision_10: 0.8996 - recall_10: 0.8987 - val_loss: 0.4909 - val_accuracy: 0.7982 - val_precision_10: 0.7895 - val_recall_10: 0.8681
# Epoch 34/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.3321 - accuracy: 0.8815 - precision_10: 0.8928 - recall_10: 0.8967 - val_loss: 0.4670 - val_accuracy: 0.8021 - val_precision_10: 0.8458 - val_recall_10: 0.7870
# Epoch 35/90
# 219/219 [==============================] - 3s 12ms/step - loss: 0.3348 - accuracy: 0.8826 - precision_10: 0.8938 - recall_10: 0.8977 - val_loss: 0.4827 - val_accuracy: 0.7982 - val_precision_10: 0.8378 - val_recall_10: 0.7894
# Epoch 36/90
# 219/219 [==============================] - 2s 10ms/step - loss: 0.3302 - accuracy: 0.8861 - precision_10: 0.8935 - recall_10: 0.9051 - val_loss: 0.4667 - val_accuracy: 0.8008 - val_precision_10: 0.8337 - val_recall_10: 0.8009
# Epoch 37/90
# 219/219 [==============================] - 2s 8ms/step - loss: 0.3304 - accuracy: 0.8836 - precision_10: 0.8936 - recall_10: 0.9000 - val_loss: 0.4663 - val_accuracy: 0.8059 - val_precision_10: 0.8275 - val_recall_10: 0.8218
# Epoch 38/90
# 219/219 [==============================] - 2s 8ms/step - loss: 0.3237 - accuracy: 0.8891 - precision_10: 0.8952 - recall_10: 0.9089 - val_loss: 0.4750 - val_accuracy: 0.8046 - val_precision_10: 0.8139 - val_recall_10: 0.8403
# Epoch 39/90
# 219/219 [==============================] - 2s 8ms/step - loss: 0.3204 - accuracy: 0.8895 - precision_10: 0.8965 - recall_10: 0.9081 - val_loss: 0.4816 - val_accuracy: 0.8021 - val_precision_10: 0.8203 - val_recall_10: 0.8241
# Epoch 40/90
# 219/219 [==============================] - 2s 8ms/step - loss: 0.3264 - accuracy: 0.8853 - precision_10: 0.8937 - recall_10: 0.9033 - val_loss: 0.4819 - val_accuracy: 0.8033 - val_precision_10: 0.8149 - val_recall_10: 0.8356
# Epoch 41/90
# 219/219 [==============================] - 2s 8ms/step - loss: 0.3245 - accuracy: 0.8871 - precision_10: 0.8962 - recall_10: 0.9035 - val_loss: 0.4829 - val_accuracy: 0.7982 - val_precision_10: 0.7919 - val_recall_10: 0.8634
# Epoch 42/90
# 219/219 [==============================] - 2s 10ms/step - loss: 0.3237 - accuracy: 0.8861 - precision_10: 0.8973 - recall_10: 0.9002 - val_loss: 0.4668 - val_accuracy: 0.8059 - val_precision_10: 0.8215 - val_recall_10: 0.8310
# Epoch 43/90
# 219/219 [==============================] - 2s 11ms/step - loss: 0.3207 - accuracy: 0.8886 - precision_10: 0.8961 - recall_10: 0.9068 - val_loss: 0.4736 - val_accuracy: 0.8021 - val_precision_10: 0.8131 - val_recall_10: 0.8356
# Epoch 44/90
# 219/219 [==============================] - 2s 9ms/step - loss: 0.3156 - accuracy: 0.8881 - precision_10: 0.8934 - recall_10: 0.9091 - val_loss: 0.4725 - val_accuracy: 0.8046 - val_precision_10: 0.8111 - val_recall_10: 0.8449
# Epoch 45/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.3197 - accuracy: 0.8893 - precision_10: 0.8969 - recall_10: 0.9074 - val_loss: 0.4836 - val_accuracy: 0.8059 - val_precision_10: 0.8061 - val_recall_10: 0.8565
# Epoch 46/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.3168 - accuracy: 0.8855 - precision_10: 0.8918 - recall_10: 0.9061 - val_loss: 0.4757 - val_accuracy: 0.8008 - val_precision_10: 0.8337 - val_recall_10: 0.8009
# Epoch 47/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.3149 - accuracy: 0.8902 - precision_10: 0.8992 - recall_10: 0.9061 - val_loss: 0.5162 - val_accuracy: 0.7956 - val_precision_10: 0.7803 - val_recall_10: 0.8796
# Epoch 48/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.3120 - accuracy: 0.8908 - precision_10: 0.8971 - recall_10: 0.9099 - val_loss: 0.4784 - val_accuracy: 0.8059 - val_precision_10: 0.8230 - val_recall_10: 0.8287
# Epoch 49/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.3159 - accuracy: 0.8898 - precision_10: 0.8997 - recall_10: 0.9046 - val_loss: 0.4848 - val_accuracy: 0.8085 - val_precision_10: 0.8268 - val_recall_10: 0.8287
# Epoch 50/90
# 219/219 [==============================] - 2s 9ms/step - loss: 0.3093 - accuracy: 0.8929 - precision_10: 0.8999 - recall_10: 0.9107 - val_loss: 0.4878 - val_accuracy: 0.8072 - val_precision_10: 0.8026 - val_recall_10: 0.8657
# Epoch 51/90
# 219/219 [==============================] - 2s 11ms/step - loss: 0.3106 - accuracy: 0.8918 - precision_10: 0.8947 - recall_10: 0.9150 - val_loss: 0.4949 - val_accuracy: 0.8123 - val_precision_10: 0.8206 - val_recall_10: 0.8472
# Epoch 52/90
# 219/219 [==============================] - 2s 8ms/step - loss: 0.3090 - accuracy: 0.8952 - precision_10: 0.8991 - recall_10: 0.9163 - val_loss: 0.4906 - val_accuracy: 0.8021 - val_precision_10: 0.8310 - val_recall_10: 0.8079
# Epoch 53/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.3035 - accuracy: 0.8951 - precision_10: 0.8995 - recall_10: 0.9155 - val_loss: 0.4938 - val_accuracy: 0.8059 - val_precision_10: 0.7996 - val_recall_10: 0.8681
# Epoch 54/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.3099 - accuracy: 0.8885 - precision_10: 0.8951 - recall_10: 0.9079 - val_loss: 0.4970 - val_accuracy: 0.8098 - val_precision_10: 0.8100 - val_recall_10: 0.8588
# Epoch 55/90
# 219/219 [==============================] - 2s 8ms/step - loss: 0.3059 - accuracy: 0.8909 - precision_10: 0.8959 - recall_10: 0.9117 - val_loss: 0.5123 - val_accuracy: 0.8085 - val_precision_10: 0.8209 - val_recall_10: 0.8380
# Epoch 56/90
# 219/219 [==============================] - 2s 8ms/step - loss: 0.2960 - accuracy: 0.8965 - precision_10: 0.9011 - recall_10: 0.9163 - val_loss: 0.5197 - val_accuracy: 0.8072 - val_precision_10: 0.8052 - val_recall_10: 0.8611
# Epoch 57/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.3024 - accuracy: 0.8934 - precision_10: 0.8974 - recall_10: 0.9147 - val_loss: 0.5019 - val_accuracy: 0.8111 - val_precision_10: 0.8132 - val_recall_10: 0.8565
# Epoch 58/90
# 219/219 [==============================] - 2s 9ms/step - loss: 0.3017 - accuracy: 0.8928 - precision_10: 0.8967 - recall_10: 0.9145 - val_loss: 0.5087 - val_accuracy: 0.8098 - val_precision_10: 0.8333 - val_recall_10: 0.8218
# Epoch 59/90
# 219/219 [==============================] - 2s 11ms/step - loss: 0.2989 - accuracy: 0.8998 - precision_10: 0.9013 - recall_10: 0.9226 - val_loss: 0.5103 - val_accuracy: 0.8085 - val_precision_10: 0.8238 - val_recall_10: 0.8333
# Epoch 60/90
# 219/219 [==============================] - 2s 9ms/step - loss: 0.2954 - accuracy: 0.8959 - precision_10: 0.8996 - recall_10: 0.9170 - val_loss: 0.5146 - val_accuracy: 0.8033 - val_precision_10: 0.8026 - val_recall_10: 0.8565
# Epoch 61/90
# 219/219 [==============================] - 2s 8ms/step - loss: 0.2925 - accuracy: 0.8962 - precision_10: 0.8961 - recall_10: 0.9221 - val_loss: 0.5013 - val_accuracy: 0.8085 - val_precision_10: 0.8043 - val_recall_10: 0.8657
# Epoch 62/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.2914 - accuracy: 0.8999 - precision_10: 0.9011 - recall_10: 0.9231 - val_loss: 0.5250 - val_accuracy: 0.8046 - val_precision_10: 0.7991 - val_recall_10: 0.8657
# Epoch 63/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.2956 - accuracy: 0.8941 - precision_10: 0.8977 - recall_10: 0.9158 - val_loss: 0.5020 - val_accuracy: 0.8021 - val_precision_10: 0.8458 - val_recall_10: 0.7870
# Epoch 64/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.2916 - accuracy: 0.8968 - precision_10: 0.8988 - recall_10: 0.9198 - val_loss: 0.5045 - val_accuracy: 0.8123 - val_precision_10: 0.8250 - val_recall_10: 0.8403
# Epoch 65/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.2947 - accuracy: 0.8945 - precision_10: 0.8962 - recall_10: 0.9186 - val_loss: 0.5067 - val_accuracy: 0.8021 - val_precision_10: 0.7996 - val_recall_10: 0.8588
# Epoch 66/90
# 219/219 [==============================] - 2s 9ms/step - loss: 0.2839 - accuracy: 0.8991 - precision_10: 0.9022 - recall_10: 0.9201 - val_loss: 0.5065 - val_accuracy: 0.8033 - val_precision_10: 0.8013 - val_recall_10: 0.8588
# Epoch 67/90
# 219/219 [==============================] - 2s 11ms/step - loss: 0.2863 - accuracy: 0.8981 - precision_10: 0.8988 - recall_10: 0.9224 - val_loss: 0.5199 - val_accuracy: 0.8111 - val_precision_10: 0.8188 - val_recall_10: 0.8472
# Epoch 68/90
# 219/219 [==============================] - 2s 9ms/step - loss: 0.2925 - accuracy: 0.8925 - precision_10: 0.8962 - recall_10: 0.9145 - val_loss: 0.5197 - val_accuracy: 0.8136 - val_precision_10: 0.8254 - val_recall_10: 0.8426
# Epoch 69/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.2828 - accuracy: 0.8996 - precision_10: 0.9005 - recall_10: 0.9234 - val_loss: 0.5581 - val_accuracy: 0.8046 - val_precision_10: 0.7991 - val_recall_10: 0.8657
# Epoch 70/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.2831 - accuracy: 0.9005 - precision_10: 0.9018 - recall_10: 0.9234 - val_loss: 0.5414 - val_accuracy: 0.8085 - val_precision_10: 0.8268 - val_recall_10: 0.8287
# Epoch 71/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.2808 - accuracy: 0.9001 - precision_10: 0.8992 - recall_10: 0.9259 - val_loss: 0.5138 - val_accuracy: 0.8123 - val_precision_10: 0.8250 - val_recall_10: 0.8403
# Epoch 72/90
# 219/219 [==============================] - 2s 8ms/step - loss: 0.2823 - accuracy: 0.8991 - precision_10: 0.8992 - recall_10: 0.9239 - val_loss: 0.5270 - val_accuracy: 0.8046 - val_precision_10: 0.8043 - val_recall_10: 0.8565
# Epoch 73/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.2791 - accuracy: 0.9006 - precision_10: 0.9040 - recall_10: 0.9208 - val_loss: 0.5441 - val_accuracy: 0.8111 - val_precision_10: 0.8146 - val_recall_10: 0.8542
# Epoch 74/90
# 219/219 [==============================] - 2s 9ms/step - loss: 0.2806 - accuracy: 0.8985 - precision_10: 0.9005 - recall_10: 0.9211 - val_loss: 0.5433 - val_accuracy: 0.8033 - val_precision_10: 0.7925 - val_recall_10: 0.8750
# Epoch 75/90
# 219/219 [==============================] - 3s 12ms/step - loss: 0.2795 - accuracy: 0.9016 - precision_10: 0.9020 - recall_10: 0.9254 - val_loss: 0.5087 - val_accuracy: 0.8033 - val_precision_10: 0.7987 - val_recall_10: 0.8634
# Epoch 76/90
# 219/219 [==============================] - 2s 9ms/step - loss: 0.2806 - accuracy: 0.9005 - precision_10: 0.9030 - recall_10: 0.9219 - val_loss: 0.5416 - val_accuracy: 0.7995 - val_precision_10: 0.7911 - val_recall_10: 0.8681
# Epoch 77/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.2799 - accuracy: 0.9006 - precision_10: 0.8989 - recall_10: 0.9275 - val_loss: 0.5786 - val_accuracy: 0.8033 - val_precision_10: 0.8026 - val_recall_10: 0.8565
# Epoch 78/90
# 219/219 [==============================] - 2s 7ms/step - loss: 0.2739 - accuracy: 0.9034 - precision_10: 0.9003 - recall_10: 0.9310 - val_loss: 0.5854 - val_accuracy: 0.8059 - val_precision_10: 0.7983 - val_recall_10: 0.8704
# Epoch 79/90
# 219/219 [==============================] - 2s 8ms/step - loss: 0.2774 - accuracy: 0.8996 - precision_10: 0.9017 - recall_10: 0.9219 - val_loss: 0.5258 - val_accuracy: 0.8046 - val_precision_10: 0.8030 - val_recall_10: 0.8588
# Epoch 80/90
# 219/219 [==============================] - 2s 8ms/step - loss: 0.2698 - accuracy: 0.9025 - precision_10: 0.9026 - recall_10: 0.9264 - val_loss: 0.5477 - val_accuracy: 0.7982 - val_precision_10: 0.7919 - val_recall_10: 0.8634
# Epoch 81/90
# 219/219 [==============================] - 2s 8ms/step - loss: 0.2696 - accuracy: 0.9041 - precision_10: 0.9044 - recall_10: 0.9272 - val_loss: 0.5190 - val_accuracy: 0.8149 - val_precision_10: 0.8214 - val_recall_10: 0.8519
# Epoch 82/90
# 219/219 [==============================] - 2s 10ms/step - loss: 0.2693 - accuracy: 0.9025 - precision_10: 0.9002 - recall_10: 0.9295 - val_loss: 0.5396 - val_accuracy: 0.8085 - val_precision_10: 0.8329 - val_recall_10: 0.8194
# Epoch 83/90
# 219/219 [==============================] - 2s 11ms/step - loss: 0.2684 - accuracy: 0.9044 - precision_10: 0.9025 - recall_10: 0.9303 - val_loss: 0.5455 - val_accuracy: 0.8098 - val_precision_10: 0.8349 - val_recall_10: 0.8194
# Epoch 84/90
# 219/219 [==============================] - 2s 9ms/step - loss: 0.2695 - accuracy: 0.8988 - precision_10: 0.9003 - recall_10: 0.9219 - val_loss: 0.5405 - val_accuracy: 0.8085 - val_precision_10: 0.8298 - val_recall_10: 0.8241
# Epoch 85/90
# 219/219 [==============================] - 2s 8ms/step - loss: 0.2748 - accuracy: 0.9001 - precision_10: 0.9023 - recall_10: 0.9219 - val_loss: 0.5562 - val_accuracy: 0.8059 - val_precision_10: 0.8048 - val_recall_10: 0.8588
# Epoch 86/90
# 219/219 [==============================] - 2s 8ms/step - loss: 0.2635 - accuracy: 0.9059 - precision_10: 0.9053 - recall_10: 0.9298 - val_loss: 0.5476 - val_accuracy: 0.8111 - val_precision_10: 0.8132 - val_recall_10: 0.8565
# Epoch 87/90
# 219/219 [==============================] - 2s 8ms/step - loss: 0.2664 - accuracy: 0.9028 - precision_10: 0.9024 - recall_10: 0.9272 - val_loss: 0.5667 - val_accuracy: 0.8149 - val_precision_10: 0.8243 - val_recall_10: 0.8472
# Epoch 88/90
# 219/219 [==============================] - 2s 8ms/step - loss: 0.2642 - accuracy: 0.9014 - precision_10: 0.9024 - recall_10: 0.9244 - val_loss: 0.5658 - val_accuracy: 0.7956 - val_precision_10: 0.7826 - val_recall_10: 0.8750
# Epoch 89/90
# 219/219 [==============================] - 2s 8ms/step - loss: 0.2630 - accuracy: 0.9022 - precision_10: 0.9039 - recall_10: 0.9242 - val_loss: 0.5717 - val_accuracy: 0.8111 - val_precision_10: 0.8105 - val_recall_10: 0.8611
# Epoch 90/90
# 219/219 [==============================] - 2s 11ms/step - loss: 0.2661 - accuracy: 0.8992 - precision_10: 0.9014 - recall_10: 0.9214 - val_loss: 0.5963 - val_accuracy: 0.7995 - val_precision_10: 0.7887 - val_recall_10: 0.8727

# %%
def plot_graphs(history, metric):
    plt.plot(history.history[metric])
    plt.plot(history.history[f'val_{metric}'])
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend([metric, f'val_{metric}'])
    plt.show()
    
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")
